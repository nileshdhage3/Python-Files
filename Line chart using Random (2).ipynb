# %%
import matplotlib.pyplot as plt
import numpy as np
import random

# %%
age=np.random.randint(10,20,(10))

# %%
age
# Out:
# array([11, 14, 12, 13, 17, 18, 11, 15, 10, 12])

# %%
dict=["ab","bc","cd","sd","Er","gh","sd","ty","uy","po"]

# %%
dict
# Out:
# ['ab', 'bc', 'cd', 'sd', 'Er', 'gh', 'sd', 'ty', 'uy', 'po']

# %%
plt.plot(age)

# %%
plt.bar(age,dict)
# Out:
# <BarContainer object of 10 artists>

# %%
plt.barh(age,dict)
# Out:
# <BarContainer object of 10 artists>

# %%
agea=np.random.randint(30,40,(10))

# %%
agea
# Out:
# array([31, 37, 32, 30, 38, 31, 36, 31, 38, 38])
