# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import random
from matplotlib import style

# %%
plt.figure(figsize=(24,16))

# Line Chart using Random numbers
plt.subplot(3,2,1)
plt.plot(num1,'b--',label="Random 1",linestyle='-',marker='+')
plt.plot(num2,'r--',label="Random 2",linestyle='-.',marker='o')
plt.title("Random data")
plt.xlabel("Random numbeer 1")
plt.ylabel("Random numbeer 2")
plt.legend(loc=4)


# Scatter plot using Random numbers
plt.subplot(3,2,2)
num1=np.random.randint(20,50,(20))
num2=np.random.randint(30,60,(20))
plt.scatter(num1,num2)


# Pie Chart using Random numbers
plt.subplot(3,2,3)
num3=np.random.randint(20,50,(10))
names=['Java','.Net','Python','ML','R Lang','Ruby','Php','html','Javascript','C++']
plt.pie(num3,labels=names)
num3


# Histogram
plt.subplot(3,2,4)
ml_age=np.random.randint(20,30,(10))
ds_age=np.random.randint(20,30,(10))
plt.hist([ml_age,ds_age],bins=6,rwidth=0.5, orientation='vertical',color=['m','y'], label=["ML Student","DS Student"])
plt.title("Student details")
plt.xlabel("Age")
plt.ylabel("no of student")
plt.legend()


# Bar Chart
plt.subplot(3,2,5)
classes=["DS","Python","ML"]
class1=[98,78,85]
class2=[23,26,54]
class3=[45,66,70]
classes_index=np.arange(len(classes))
width=0.3
plt.bar(classes_index, class1, width, color='b', label='Class 1')
plt.bar(classes_index + width, class2, width, color='g', label='Class 2')
plt.bar(classes_index + width + width, class3, width, color='r', label='Class 3')
plt.legend()
plt.xticks(classes_index + width, classes, rotation=15)

#Sub plot using sub plot parameters
plt.subplot(3,2,6,projection='polar',facecolor='red')


plt.show()
