# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data=pd.read_csv("covid_india.csv")

# %%
data.head()
# Out:
#    S. No.   Name of State / UT  Active Cases  Cured/Discharged/Migrated  \
# 0       1  Andaman and Nicobar           193                       6630
# 1       2       Andhra Pradesh        180362                    1466990
# 2       3    Arunachal Pradesh          3854                      22352
# 3       4                Assam         54664                     340178
# 4       5                Bihar         24810                     672868
#
#    Deaths  Total Confirmed cases
# 0     113                   6936
# 1   10634                1657986
# 2     111                  26317
# 3    3168                 398010
# 4    5004                 702682

# %%
data.columns
# Out:
# Index(['S. No.', 'Name of State / UT', 'Active Cases',
#        'Cured/Discharged/Migrated', 'Deaths', 'Total Confirmed cases'],
#       dtype='object')

# %%
data.shape
# Out:
# (36, 6)

# %%
data.tail()
# Out:
#     S. No. Name of State / UT  Active Cases  Cured/Discharged/Migrated  \
# 31      32          Telengana         37793                     530025
# 32      33            Tripura          6919                      42468
# 33      34      Uttar Pradesh         52244                    1613841
# 34      35        Uttarakhand         33994                     285170
# 35      36        West Bengal        109806                    1218516
#
#     Deaths  Total Confirmed cases
# 31    3226                 571044
# 32     498                  49885
# 33   20053                1686138
# 34    6261                 325425
# 35   15120                1343442

# %%
data.describe()
# Out:
#           S. No.   Active Cases  Cured/Discharged/Migrated        Deaths  \
# count  36.000000      36.000000               3.600000e+01     36.000000
# mean   18.500000   61909.000000               6.993892e+05   8958.666667
# std    10.535654   95478.669696               1.015199e+06  16284.617820
# min     1.000000     193.000000               5.404000e+03      4.000000
# 25%     9.750000    6436.750000               3.592650e+04    532.500000
# 50%    18.500000   24942.500000               3.294335e+05   3510.500000
# 75%    27.250000   52849.000000               8.737215e+05   9979.250000
# max    36.000000  372394.000000               5.307874e+06  93198.000000
#
#        Total Confirmed cases
# count           3.600000e+01
# mean            7.702569e+05
# std             1.107640e+06
# min             6.936000e+03
# 25%             4.434100e+04
# 50%             3.667135e+05
# 75%             9.416880e+05
# max             5.692920e+06

# %%
data.isnull().sum()
# Out:
# S. No.                       0
# Name of State / UT           0
# Active Cases                 0
# Cured/Discharged/Migrated    0
# Deaths                       0
# Total Confirmed cases        0
# dtype: int64

# %% [markdown]
# # Relating data with scatterplot

# %%
data.columns
# Out:
# Index(['S. No.', 'Name of State / UT', 'Active Cases',
#        'Cured/Discharged/Migrated', 'Deaths', 'Total Confirmed cases'],
#       dtype='object')

# %%
sns.relplot(x="Active Cases",y="Cured/Discharged/Migrated",data=data)

# %%
sns.relplot(x="Active Cases",y="Deaths",data=data)

# %%
sns.relplot(x="Name of State / UT",y="Active Cases", hue="Active Cases", data=data)

# %%
sns.pairplot(data)

# %%
data.columns
# Out:
# Index(['S. No.', 'Name of State / UT', 'Active Cases',
#        'Cured/Discharged/Migrated', 'Deaths', 'Total Confirmed cases'],
#       dtype='object')

# %%
sns.relplot(x='Active Cases',y='Deaths',kind='line', data=data)

# %%
sns.catplot(x='Active Cases',y='Cured/Discharged/Migrated',data=data)
